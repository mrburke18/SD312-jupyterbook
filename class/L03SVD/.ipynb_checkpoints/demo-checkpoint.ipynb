# %%
import numpy as np

# %%
ratings=np.array([[5,2,4.5],[1,4,1],[4,1,4],[2,2,1.5]])
print(ratings)

# %%
u,s,vt=np.linalg.svd(ratings)

# %%
print(u.shape)
print(u)
print()
print(s.shape)
print(s)
print()
print(vt.shape)
print(vt)

# %%
Sigma=np.zeros((4,3))
Sigma[:3,:3]=np.diag(s)
print(Sigma)

# %%
print(u@Sigma@vt)

# %%
s[-1]=0
Sigma=np.zeros((4,3))
Sigma[:3,:3]=np.diag(s)
print(Sigma)

# %%
print(u@Sigma@vt)
